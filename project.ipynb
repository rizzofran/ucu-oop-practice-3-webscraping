# %% [markdown]
# # UCU - Proyecto Webscraping
# Proyecto para la Licenciatura en Datos y Negocios de la Universidad Católica del Uruguay

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.infocasas.com.uy/venta/inmuebles/montevideo'

response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %% [markdown]
# Saco el link de la página correspondiente a las propiedades en Montevideo

# %%
url_mvd = "https://www.infocasas.com.uy/venta/casas/montevideo"
response_mvd = requests.get(url_mvd, headers=headers)
soup_mvd = BeautifulSoup(response_mvd.text, "html.parser")

soup_mvd
# Out:
# <!DOCTYPE html>
# <html class="infocasas-theme" id="bodyTag" lang="es-UY"><head><link as="font" crossorigin="anonymous" href="https://cdn4.fincaraiz.com.co/web/5fdcaa52b06cf_infocdn__infocasas-regular.woff2" rel="preload" type="font/woff"/><link as="font" crossorigin="anonymous" href="https://cdn4.fincaraiz.com.co/web/5fdcaa52af7c5_infocdn__infocasas-bold.woff2" rel="preload" type="font/woff"/><script>
# 								function getWidth() {
# 								return Math.max(
# 									document.body.scrollWidth,
# 									document.documentElement.scrollWidth,
# 									document.body.offsetWidth,
# 									document.documentElement.offsetWidth,
# 									document.documentElement.clientWidth
# 								);
# 								}
#
# 								function setHeightPushdown(expanded) {
# 								const width = getWidth();
# 								const expandible = document.getElementById('expandible');
# 								if (expandible) {
# 									const expandedHeight = width < 600 ? '250px' : '250px';
# ...

# %% [markdown]
# Una vez identificada la estructura del HTML, se obtiene la información relevante del anuncio

# %%
# Lista donde guardo las propiedades de Montevideo
propiedades_mvd = []

# %%
# Recorro todos los anuncios y tomo solamente 10
for anuncio in soup_mvd.find_all("div", class_:="listingCard")[:10]:
    try:
        # Saco el precio
        precio = anuncio.find("p", class_="main-price").get_text(strip=True)

        # Saco info adicional
        tags = anuncio.find_all("span", class_="lc-typologyTag_item")

        # Cuartos
        cuartos = tags[0].get_text(strip=True) if len(tags) > 0 else None

        # Baños
        banos = tags[1].get_text(strip=True) if len(tags) > 1 else None

        # Tamaño
        tamano = tags[2].get_text(strip=True) if len(tags) > 2 else None

     # Guardamos los datos en un diccionario y lo agregamos a la lista
        propiedades_mvd.append({
            "precio": precio,
            "tamano": tamano,
            "habitaciones": dorms,
        })

    except Exception as e:
        # Si hay un error en este anuncio, lo saltamos y seguimos con el siguiente
        continue

# Mostramos los primeros 3 resultados para verificar que funciona
print("Montevideo:")
print(propiedades_mvd[:3])
# Out:
# Montevideo:
# [{'precio': 'U$S 235.000', 'tamano': None, 'habitaciones': '2 Dorms.'}, {'precio': 'U$S 220.000', 'tamano': None, 'habitaciones': '2 Dorms.'}, {'precio': 'U$S 265.000', 'tamano': None, 'habitaciones': '2 Dorms.'}]

# %%
url_pde = "https://www.infocasas.com.uy/venta/casas/punta-del-este"
response_pde = requests.get(url_pde, headers=headers)
soup_pde = BeautifulSoup(response_pde.text, "html.parser")

propiedades_pde = []
for anuncio in soup_pde.find_all("div", class_="listingCard")[:10]:
    try:
        precio = anuncio.find("p", class_="main-price").get_text(strip=True)
        tags = anuncio.find_all("span", class_="lc-typologyTag__item")
        dorms = tags[0].get_text(strip=True) if len(tags) > 0 else None
        banos = tags[1].get_text(strip=True) if len(tags) > 1 else None
        tamano = tags[2].get_text(strip=True) if len(tags) > 2 else None

        propiedades_pde.append({
            "precio": precio,
            "tamano": tamano,
            "habitaciones": dorms,
        })
    except Exception as e:
        continue

print("Punta del Este:")
print(propiedades_pde[:3])
# Out:
# Punta del Este:
# [{'precio': 'U$S 1.300.000', 'tamano': '670m²', 'habitaciones': '11 Dorms.'}, {'precio': 'U$S 247.000', 'tamano': '137m²', 'habitaciones': '3 Dorms.'}, {'precio': 'U$S 2.200.000', 'tamano': '586m²', 'habitaciones': '4 Dorms.'}]

# %%
url_paysandu = "https://www.infocasas.com.uy/venta/casas/paysandu"
response_paysandu = requests.get(url_paysandu, headers=headers)
soup_paysandu = BeautifulSoup(response_paysandu.text, "html.parser")

propiedades_paysandu = []
for anuncio in soup_paysandu.find_all("div", class_="listingCard")[:10]:
    try:
        precio = anuncio.find("p", class_="main-price").get_text(strip=True)
        tags = anuncio.find_all("span", class_="lc-typologyTag__item")
        dorms = tags[0].get_text(strip=True) if len(tags) > 0 else None
        banos = tags[1].get_text(strip=True) if len(tags) > 1 else None
        tamano = tags[2].get_text(strip=True) if len(tags) > 2 else None

        propiedades_paysandu.append({
            "precio": precio,
            "tamano": tamano,
            "habitaciones": dorms,
        })
    except Exception as e:
        continue

print("Paysandú:")
print(propiedades_paysandu[:3])
# Out:
# Paysandú:
# [{'precio': 'U$S 117.000', 'tamano': '120m²', 'habitaciones': '3 Dorms.'}, {'precio': 'U$S 450.000', 'tamano': '355m²', 'habitaciones': '4 Dorms.'}, {'precio': 'U$S 270.000', 'tamano': '206m²', 'habitaciones': '4 Dorms.'}]

# %%
import json

# Armamos la estructura con las tres ciudades
data = {
    "ciudades": [
        {
            "nombre": "Montevideo",
            "propiedades": propiedades_mvd
        },
        {
            "nombre": "Punta del Este",
            "propiedades": propiedades_pde
        },
        {
            "nombre": "Paysandú",
            "propiedades": propiedades_paysandu
        }
    ]
}

# Guardo en un archivo JSON
with open("propiedades.json", "w", encoding="utf-8") as f:
    # indent=2 → formato legible
    # ensure_ascii=False → mantiene acentos y caracteres especiales
    json.dump(data, f, indent=2, ensure_ascii=False)

print(json.dumps(data, indent=2, ensure_ascii=False))
# Out:
# {
#   "ciudades": [
#     {
#       "nombre": "Montevideo",
#       "propiedades": [
#         {
#           "precio": "U$S 235.000",
#           "tamano": null,
#           "habitaciones": "2 Dorms."
#         },
#         {
#           "precio": "U$S 220.000",
#           "tamano": null,
#           "habitaciones": "2 Dorms."
#         },
#         {
#           "precio": "U$S 265.000",
#           "tamano": null,
#           "habitaciones": "2 Dorms."
#         },
#         {
#           "precio": "U$S 970.000",
#           "tamano": null,
#           "habitaciones": "2 Dorms."
#         },
#         {
#           "precio": "U$S 850.000",
#           "tamano": null,
#           "habitaciones": "2 Dorms."
#         },
#         {
#           "precio": "U$S 359.000",
#           "tamano": null,
#           "habitaciones": "2 Dorms."
#         },
#         {
#           "precio": "U$S 1.900.000",
#           "tamano": null,
#           "habitaciones": "2 Dorms."
#         },
# ...
